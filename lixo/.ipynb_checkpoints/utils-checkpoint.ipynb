# %%
import pandas as pd

def read_gmt_hier(file_name):
    gmt_names = []
    gmt_desc  = []
    gmt_genes = []
    res =pd.DataFrame()

    with open("exemplo.gmt", 'r') as f:
        # separar cada elemento separado por tab e guardar eles
        for line in f:
            gmt_names.append(line.split("\t")[0])
            gmt_desc.append(line.split("\t")[1])
            gmt_genes.append(line.split("\t")[2:])

    for i in range(len(gmt_genes)) :

        # apagar \n presente no ultimo gene de cada lista (artefato da leitura do arquivo)
        gmt_genes[i][-1] = gmt_genes[i][-1].replace("\n", "")

        # Poem na forma de um dataframe, cada linha um gene e suas informações relativas 
        temp= pd.DataFrame({'term': [gmt_names[i]]*len(gmt_genes[i]), 'hier':  [gmt_desc[i]]*len(gmt_genes[i]), 'gene' : gmt_genes[i] })
        res = pd.concat([res,temp])

    # reseta o indice
    res = res.reset_index(drop=True)    

    #relação entre nomes e descricões  (é pra isso q essa variavel serve? no original é um datafra esquisito, achei q assim ia ser mais otimizado)   
    path_desc = dict(zip(gmt_names,gmt_desc))

    return res, path_desc

# %%
res, _ =read_gmt_hier("exemplo.gmt")

# %%
res
# Out:
#            gene           hier                                  term
# 0        IZUMO4  R_HSA_1187000                         Fertilization
# 1         OVGP1  R_HSA_1187000                         Fertilization
# 2        IZUMO3  R_HSA_1187000                         Fertilization
# 3        IZUMO2  R_HSA_1187000                         Fertilization
# 4        IZUMO1  R_HSA_1187000                         Fertilization
# 5        ADAM30  R_HSA_1187000                         Fertilization
# 6           ACR  R_HSA_1187000                         Fertilization
# 7      CATSPERB  R_HSA_1187000                         Fertilization
# 8         SPAM1  R_HSA_1187000                         Fertilization
# 9         KCNU1  R_HSA_1187000                         Fertilization
# 10        ADAM2  R_HSA_1187000                         Fertilization
# 11     CATSPERD  R_HSA_1187000                         Fertilization
# 12          CD9  R_HSA_1187000                         Fertilization
# 13     CATSPERG  R_HSA_1187000                         Fertilization
# 14          ZP2  R_HSA_1187000                         Fertilization
# 15          ZP1  R_HSA_1187000                         Fertilization
# 16          ZP4  R_HSA_1187000                         Fertilization
# 17          ZP3  R_HSA_1187000                         Fertilization
# 18     CATSPER2  R_HSA_1187000                         Fertilization
# 19     CATSPER1  R_HSA_1187000                         Fertilization
# 20      B4GALT1  R_HSA_1187000                         Fertilization
# 21     CATSPER4  R_HSA_1187000                         Fertilization
# 22     CATSPER3  R_HSA_1187000                         Fertilization
# 23        HVCN1  R_HSA_1187000                         Fertilization
# 24       ADAM21  R_HSA_1187000                         Fertilization
# 25       ADAM20  R_HSA_1187000                         Fertilization
# 26       IZUMO4  R_HSA_1474165                          Reproduction
# 27        OVGP1  R_HSA_1474165                          Reproduction
# 28       IZUMO3  R_HSA_1474165                          Reproduction
# 29       IZUMO2  R_HSA_1474165                          Reproduction
# ...         ...            ...                                   ...
# 33925    MRPL10  R_HSA_5389840  Mitochondrial translation elongation
# 33926    MRPL51  R_HSA_5389840  Mitochondrial translation elongation
# 33927    MRPL52  R_HSA_5389840  Mitochondrial translation elongation
# 33928    MRPL50  R_HSA_5389840  Mitochondrial translation elongation
# 33929  AURKAIP1  R_HSA_5389840  Mitochondrial translation elongation
# 33930      GFM1  R_HSA_5389840  Mitochondrial translation elongation
# 33931    MRPS36  R_HSA_5389840  Mitochondrial translation elongation
# 33932    MRPL19  R_HSA_5389840  Mitochondrial translation elongation
# 33933    MRPS34  R_HSA_5389840  Mitochondrial translation elongation
# 33934    MRPS35  R_HSA_5389840  Mitochondrial translation elongation
# 33935    MRPL17  R_HSA_5389840  Mitochondrial translation elongation
# 33936    MRPS33  R_HSA_5389840  Mitochondrial translation elongation
# 33937    MRPL18  R_HSA_5389840  Mitochondrial translation elongation
# 33938    MRPL15  R_HSA_5389840  Mitochondrial translation elongation
# 33939    MRPS30  R_HSA_5389840  Mitochondrial translation elongation
# 33940    MRPS31  R_HSA_5389840  Mitochondrial translation elongation
# 33941    MRPL16  R_HSA_5389840  Mitochondrial translation elongation
# 33942     MRPL1  R_HSA_5389840  Mitochondrial translation elongation
# 33943    MRPL13  R_HSA_5389840  Mitochondrial translation elongation
# 33944    MRPL14  R_HSA_5389840  Mitochondrial translation elongation
# 33945    MRPL55  R_HSA_5389840  Mitochondrial translation elongation
# 33946    MRPL11  R_HSA_5389840  Mitochondrial translation elongation
# 33947    MRPL12  R_HSA_5389840  Mitochondrial translation elongation
# 33948    MRPL20  R_HSA_5389840  Mitochondrial translation elongation
# 33949     MRPL4  R_HSA_5389840  Mitochondrial translation elongation
# 33950    MRPL21  R_HSA_5389840  Mitochondrial translation elongation
# 33951     MRPL3  R_HSA_5389840  Mitochondrial translation elongation
# 33952     MRPL2  R_HSA_5389840  Mitochondrial translation elongation
# 33953     MRPL9  R_HSA_5389840  Mitochondrial translation elongation
# 33954    CHCHD1  R_HSA_5389840  Mitochondrial translation elongation
#
# [33955 rows x 3 columns]
