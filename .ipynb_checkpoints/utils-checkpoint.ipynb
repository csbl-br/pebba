# %%
import pandas as pd

def read_gmt_hier(file_name):
    gmt_names = []
    gmt_desc  = []
    gmt_genes = []
    res =pd.DataFrame()

    with open("exemplo.gmt", 'r') as f:
        # separar cada elemento separado por tab e guardar eles
        for line in f:
            gmt_names.append(line.split("\t")[0])
            gmt_desc.append(line.split("\t")[1])
            gmt_genes.append(line.split("\t")[2:])

    for i in range(len(gmt_genes)) :

        # apagar \n presente no ultimo gene de cada lista (artefato da leitura do arquivo)
        gmt_genes[i][-1] = gmt_genes[i][-1].replace("\n", "")

        # Poem na forma de um dataframe, cada linha um gene e suas informações relativas 
        temp= pd.DataFrame({'term': [gmt_names[i]]*len(gmt_genes[i]), 'hier':  [gmt_desc[i]]*len(gmt_genes[i]), 'gene' : gmt_genes[i] })
        res = pd.concat([res,temp])

    # reseta o indice
    res = res.reset_index(drop=True)    

    #relação entre nomes e descricões  (é pra isso q essa variavel serve? no original é um datafra esquisito, achei q assim ia ser mais otimizado)   
    path_desc = dict(zip(gmt_names,gmt_desc))

    return res, path_desc

# %%
read_gmt_hier("exemplo.gmt")
# Out:
# (           gene           hier                                  term
#  0        IZUMO4  R_HSA_1187000                         Fertilization
#  1         OVGP1  R_HSA_1187000                         Fertilization
#  2        IZUMO3  R_HSA_1187000                         Fertilization
#  3        IZUMO2  R_HSA_1187000                         Fertilization
#  4        IZUMO1  R_HSA_1187000                         Fertilization
#  5        ADAM30  R_HSA_1187000                         Fertilization
#  6           ACR  R_HSA_1187000                         Fertilization
#  7      CATSPERB  R_HSA_1187000                         Fertilization
#  8         SPAM1  R_HSA_1187000                         Fertilization
#  9         KCNU1  R_HSA_1187000                         Fertilization
#  10        ADAM2  R_HSA_1187000                         Fertilization
#  11     CATSPERD  R_HSA_1187000                         Fertilization
#  12          CD9  R_HSA_1187000                         Fertilization
#  13     CATSPERG  R_HSA_1187000                         Fertilization
#  14          ZP2  R_HSA_1187000                         Fertilization
#  15          ZP1  R_HSA_1187000                         Fertilization
#  16          ZP4  R_HSA_1187000                         Fertilization
#  17          ZP3  R_HSA_1187000                         Fertilization
#  18     CATSPER2  R_HSA_1187000                         Fertilization
#  19     CATSPER1  R_HSA_1187000                         Fertilization
#  20      B4GALT1  R_HSA_1187000                         Fertilization
#  21     CATSPER4  R_HSA_1187000                         Fertilization
#  22     CATSPER3  R_HSA_1187000                         Fertilization
#  23        HVCN1  R_HSA_1187000                         Fertilization
#  24       ADAM21  R_HSA_1187000                         Fertilization
#  25       ADAM20  R_HSA_1187000                         Fertilization
#  26       IZUMO4  R_HSA_1474165                          Reproduction
#  27        OVGP1  R_HSA_1474165                          Reproduction
#  28       IZUMO3  R_HSA_1474165                          Reproduction
#  29       IZUMO2  R_HSA_1474165                          Reproduction
#  ...         ...            ...                                   ...
#  33925    MRPL10  R_HSA_5389840  Mitochondrial translation elongation
#  33926    MRPL51  R_HSA_5389840  Mitochondrial translation elongation
#  33927    MRPL52  R_HSA_5389840  Mitochondrial translation elongation
#  33928    MRPL50  R_HSA_5389840  Mitochondrial translation elongation
#  33929  AURKAIP1  R_HSA_5389840  Mitochondrial translation elongation
#  33930      GFM1  R_HSA_5389840  Mitochondrial translation elongation
#  33931    MRPS36  R_HSA_5389840  Mitochondrial translation elongation
#  33932    MRPL19  R_HSA_5389840  Mitochondrial translation elongation
#  33933    MRPS34  R_HSA_5389840  Mitochondrial translation elongation
#  33934    MRPS35  R_HSA_5389840  Mitochondrial translation elongation
#  33935    MRPL17  R_HSA_5389840  Mitochondrial translation elongation
#  33936    MRPS33  R_HSA_5389840  Mitochondrial translation elongation
#  33937    MRPL18  R_HSA_5389840  Mitochondrial translation elongation
#  33938    MRPL15  R_HSA_5389840  Mitochondrial translation elongation
#  33939    MRPS30  R_HSA_5389840  Mitochondrial translation elongation
#  33940    MRPS31  R_HSA_5389840  Mitochondrial translation elongation
#  33941    MRPL16  R_HSA_5389840  Mitochondrial translation elongation
#  33942     MRPL1  R_HSA_5389840  Mitochondrial translation elongation
#  33943    MRPL13  R_HSA_5389840  Mitochondrial translation elongation
#  33944    MRPL14  R_HSA_5389840  Mitochondrial translation elongation
#  33945    MRPL55  R_HSA_5389840  Mitochondrial translation elongation
#  33946    MRPL11  R_HSA_5389840  Mitochondrial translation elongation
#  33947    MRPL12  R_HSA_5389840  Mitochondrial translation elongation
#  33948    MRPL20  R_HSA_5389840  Mitochondrial translation elongation
#  33949     MRPL4  R_HSA_5389840  Mitochondrial translation elongation
#  33950    MRPL21  R_HSA_5389840  Mitochondrial translation elongation
#  33951     MRPL3  R_HSA_5389840  Mitochondrial translation elongation
#  33952     MRPL2  R_HSA_5389840  Mitochondrial translation elongation
#  33953     MRPL9  R_HSA_5389840  Mitochondrial translation elongation
#  33954    CHCHD1  R_HSA_5389840  Mitochondrial translation elongation
#
#  [33955 rows x 3 columns],
#  {'A tetrasaccharide linker sequence is required for GAG synthesis': 'R_HSA_1971475',
#   'ABC transporters in lipid homeostasis': 'R_HSA_1369062',
#   'ABC_family proteins mediated transport': 'R_HSA_382556',
#   'ADP signalling through P2Y purinoceptor 1': 'R_HSA_418592',
#   'ADP signalling through P2Y purinoceptor 12': 'R_HSA_392170',
#   'APC:Cdc20 mediated degradation of cell cycle proteins prior to satisfation of the cell cycle checkpoint': 'R_HSA_179419',
#   'APC_Cdc20 mediated degradation of Nek2A': 'R_HSA_179409',
#   'APCslashC:Cdc20 mediated degradation of Cyclin B': 'R_HSA_174048',
#   'APCslashC:Cdc20 mediated degradation of Securin': 'R_HSA_174154',
#   'APCslashC:Cdc20 mediated degradation of mitotic proteins': 'R_HSA_176409',
#   'APCslashC:Cdh1 mediated degradation of Cdc20 and other APCslashC:Cdh1 targeted proteins in late mitosisslashearly G1': 'R_HSA_174178',
#   'APCslashC_mediated degradation of cell cycle proteins': 'R_HSA_174143',
#   'ATF4 activates genes': 'R_HSA_380994',
#   'AUF1 hnRNP D0 binds and destabilizes mRNA': 'R_HSA_450408',
#   'AURKA Activation by TPX2': 'R_HSA_8854518',
#   'Abortive elongation of HIV_1 transcript in the absence of Tat': 'R_HSA_167242',
#   'Acetylcholine Neurotransmitter Release Cycle': 'R_HSA_264642',
#   'Activated NOTCH1 Transmits Signal to the Nucleus': 'R_HSA_2122948',
#   'Activated PKN1 stimulates transcription of AR androgen receptor regulated genes KLK2 and KLK3': 'R_HSA_5625886',
#   'Activated point mutants of FGFR2': 'R_HSA_2033519',
#   'Activation of APCslashC and APCslashC:Cdc20 mediated degradation of mitotic proteins': 'R_HSA_176814',
#   'Activation of ATR in response to replication stress': 'R_HSA_176187',
#   'Activation of BAD and translocation to mitochondria': 'R_HSA_111447',
#   'Activation of BH3_only proteins': 'R_HSA_114452',
#   'Activation of G protein gated Potassium channels': 'R_HSA_1296041',
#   'Activation of GABAB receptors': 'R_HSA_991365',
#   'Activation of HOX genes during differentiation': 'R_HSA_5619507',
#   'Activation of IRF3slashIRF7 mediated by TBK1slashIKK epsilon': 'R_HSA_936964',
#   'Activation of Kainate Receptors upon glutamate binding': 'R_HSA_451326',
#   'Activation of Matrix Metalloproteinases': 'R_HSA_1592389',
#   'Activation of NF_kappaB in B cells': 'R_HSA_1169091',
#   'Activation of NMDA receptor upon glutamate binding and postsynaptic events': 'R_HSA_442755',
#   'Activation of SMO': 'R_HSA_5635838',
#   'Activation of anterior HOX genes in hindbrain development during early embryogenesis': 'R_HSA_5617472',
#   'Activation of gene expression by SREBF SREBP': 'R_HSA_2426168',
#   'Activation of the mRNA upon binding of the cap_binding complex and eIFs and subsequent binding to 43S': 'R_HSA_72662',
#   'Activation of the pre_replicative complex': 'R_HSA_68962',
#   'Acyl chain remodelling of PC': 'R_HSA_1482788',
#   'Acyl chain remodelling of PE': 'R_HSA_1482839',
#   'Acyl chain remodelling of PG': 'R_HSA_1482925',
#   'Acyl chain remodelling of PI': 'R_HSA_1482922',
#   'Acyl chain remodelling of PS': 'R_HSA_1482801',
#   'Adherens junctions interactions': 'R_HSA_418990',
#   'Adrenalinenoradrenaline inhibits insulin secretion': 'R_HSA_400042',
#   'Aflatoxin activation and detoxification': 'R_HSA_5423646',
#   'Amine compound SLC transporters': 'R_HSA_425428',
#   'Amine ligand_binding receptors': 'R_HSA_375280',
#   'Amine_derived hormones': 'R_HSA_209776',
#   'Amino acid and oligopeptide SLC transporters': 'R_HSA_425374',
#   'Amino acid synthesis and interconversion transamination': 'R_HSA_70614',
#   'Amino acid transport across the plasma membrane': 'R_HSA_352230',
#   'Amyloid fiber formation': 'R_HSA_977225',
#   'Anchoring of the basal body to the plasma membrane': 'R_HSA_5620912',
#   'Antigen Presentation: Folding assembly and peptide loading of class I MHC': 'R_HSA_983170',
#   'Antigen activates B Cell Receptor BCR leading to generation of second messengers': 'R_HSA_983695',
#   'Antigen processing_Cross presentation': 'R_HSA_1236975',
#   'Antiviral mechanism by IFN_stimulated genes': 'R_HSA_1169410',
#   'Apoptotic cleavage of cellular proteins': 'R_HSA_111465',
#   'Apoptotic execution  phase': 'R_HSA_75153',
#   'Aquaporin_mediated transport': 'R_HSA_445717',
#   'Arachidonic acid metabolism': 'R_HSA_2142753',
#   'Assembly of collagen fibrils and other multimeric structures': 'R_HSA_2022090',
#   'Assembly of the pre_replicative complex': 'R_HSA_68867',
#   'Association of TriCslashCCT with target proteins during biosynthesis': 'R_HSA_390471',
#   'Association of licensing factors with the pre_replicative complex': 'R_HSA_69298',
#   'Asymmetric localization of PCP proteins': 'R_HSA_4608870',
#   'Attenuation phase': 'R_HSA_3371568',
#   'Autodegradation of Cdh1 by Cdh1:APCslashC': 'R_HSA_174084',
#   'Autodegradation of the E3 ubiquitin ligase COP1': 'R_HSA_349425',
#   'BBSome_mediated cargo_targeting to cilium': 'R_HSA_5620922',
#   'BMAL1:CLOCKNPAS2 activates circadian gene expression': 'R_HSA_1368108',
#   'B_WICH complex positively regulates rRNA expression': 'R_HSA_5250924',
#   'Base Excision Repair': 'R_HSA_73884',
#   'Basigin interactions': 'R_HSA_210991',
#   'Beta defensins': 'R_HSA_1461957',
#   'Beta_catenin phosphorylation cascade': 'R_HSA_196299',
#   'Bile acid and bile salt metabolism': 'R_HSA_194068',
#   'Binding and Uptake of Ligands by Scavenger Receptors': 'R_HSA_2173782',
#   'Biosynthesis of the N_glycan precursor dolichol lipid_linked oligosaccharide LLO and transfer to a nascent protein': 'R_HSA_446193',
#   'Branched_chain amino acid catabolism': 'R_HSA_70895',
#   'Budding and maturation of HIV virion': 'R_HSA_162588',
#   'Butyrate Response Factor 1 BRF1 binds and destabilizes mRNA': 'R_HSA_450385',
#   'CD209 DC_SIGN signaling': 'R_HSA_5621575',
#   'CD22 mediated BCR regulation': 'R_HSA_5690714',
#   'CD28 co_stimulation': 'R_HSA_389356',
#   'CD28 dependent PI3KslashAkt signaling': 'R_HSA_389357',
#   'CDK_mediated phosphorylation and removal of Cdc6': 'R_HSA_69017',
#   'CDO in myogenesis': 'R_HSA_375170',
#   'CDT1 association with the CDC6:ORC:origin complex': 'R_HSA_68827',
#   'CLEC7A Dectin_1 signaling': 'R_HSA_5607764',
#   'COPII Coat Protein 2 Mediated Vesicle Transport': 'R_HSA_204005',
#   'COPI_dependent Golgi_to_ER retrograde traffic': 'R_HSA_6811434',
#   'COPI_independent Golgi_to_ER retrograde traffic': 'R_HSA_6811436',
#   'COPI_mediated anterograde transport': 'R_HSA_6807878',
#   'CREB phosphorylation through the activation of CaMKII': 'R_HSA_442729',
#   'CREB phosphorylation through the activation of Ras': 'R_HSA_442742',
#   'CRMPs in Sema3A signaling': 'R_HSA_399956',
#   'CTLA4 inhibitory signaling': 'R_HSA_389513',
#   'Ca2+ pathway': 'R_HSA_4086398',
#   'CaM pathway': 'R_HSA_111997',
#   'Ca_dependent events': 'R_HSA_111996',
#   'Calmodulin induced events': 'R_HSA_111933',
#   'Calnexinslashcalreticulin cycle': 'R_HSA_901042',
#   'Cargo concentration in the ER': 'R_HSA_5694530',
#   'Cargo trafficking to the periciliary membrane': 'R_HSA_5620920',
#   'Caspase activation via extrinsic apoptotic signalig pathway': 'R_HSA_5357769',
#   'Cdc20:Phospho_APCslashC mediated degradation of Cyclin A': 'R_HSA_174184',
#   'Cell death signalling via NRAGE NRIF and NADE': 'R_HSA_204998',
#   'Cell junction organization': 'R_HSA_446728',
#   'Cell_cell junction organization': 'R_HSA_421270',
#   'Cell_extracellular matrix interactions': 'R_HSA_446353',
#   'Cellular response to heat stress': 'R_HSA_3371556',
#   'Cellular response to hypoxia': 'R_HSA_2262749',
#   'Centrosome maturation': 'R_HSA_380287',
#   'Chaperonin_mediated protein folding': 'R_HSA_390466',
#   'Chemokine receptors bind chemokines': 'R_HSA_380108',
#   'Cholesterol biosynthesis': 'R_HSA_191273',
#   'Chondroitin sulfate biosynthesis': 'R_HSA_2022870',
#   'Chondroitin sulfateslashdermatan sulfate metabolism': 'R_HSA_1793185',
#   'Chromosome Maintenance': 'R_HSA_73886',
#   'Chylomicron_mediated lipid transport': 'R_HSA_174800',
#   'Circadian Clock': 'R_HSA_400253',
#   'Citric acid cycle TCA cycle': 'R_HSA_71403',
#   'Class Bslash2 Secretin family receptors': 'R_HSA_373080',
#   'Class Cslash3 Metabotropic glutamateslashpheromone receptors': 'R_HSA_420499',
#   'Classical antibody_mediated complement activation': 'R_HSA_173623',
#   'Clathrin derived vesicle budding': 'R_HSA_421837',
#   'Cleavage of Growing Transcript in the Termination Region': 'R_HSA_109688',
#   'Cobalamin Cbl vitamin B12 transport and metabolism': 'R_HSA_196741',
#   'Collagen biosynthesis and modifying enzymes': 'R_HSA_1650814',
#   'Collagen degradation': 'R_HSA_1442490',
#   'Collagen formation': 'R_HSA_1474290',
#   'Common Pathway of Fibrin Clot Formation': 'R_HSA_140875',
#   'Complement cascade': 'R_HSA_166658',
#   'Complex I biogenesis': 'R_HSA_6799198',
#   'Condensation of Prophase Chromosomes': 'R_HSA_2299718',
#   'Constitutive Signaling by AKT1 E17K in Cancer': 'R_HSA_5674400',
#   'Constitutive Signaling by Aberrant PI3K in Cancer': 'R_HSA_2219530',
#   'Constitutive Signaling by EGFRvIII': 'R_HSA_5637810',
#   'Constitutive Signaling by Ligand_Responsive EGFR Cancer Variants': 'R_HSA_1236382',
#   'Constitutive Signaling by NOTCH1 HD Domain Mutants': 'R_HSA_2691232',
#   'Constitutive Signaling by NOTCH1 HD+PEST Domain Mutants': 'R_HSA_2894862',
#   'Constitutive Signaling by NOTCH1 PEST Domain Mutants': 'R_HSA_2644606',
#   'Conversion from APCslashC:Cdc20 to APCslashC:Cdh1 in late anaphase': 'R_HSA_176407',
#   'Cooperation of PDCL PhLP1 and TRiCslashCCT in G_protein beta folding': 'R_HSA_6814122',
#   'Cooperation of Prefoldin and TriCslashCCT  in actin and tubulin folding': 'R_HSA_389958',
#   'Costimulation by the CD28 family': 'R_HSA_388841',
#   'Creation of C4 and C2 activators': 'R_HSA_166786',
#   'Cross_presentation of soluble exogenous antigens endosomes': 'R_HSA_1236978',
#   'Cyclin A:Cdk2_associated events at S phase entry': 'R_HSA_69656',
#   'Cyclin AslashB1 associated events during G2slashM transition': 'R_HSA_69273',
#   'Cyclin D associated events in G1': 'R_HSA_69231',
#   'Cyclin E associated events during G1slashS transition': 'R_HSA_69202',
#   'Cytochrome P450 _ arranged by substrate type': 'R_HSA_211897',
#   'Cytosolic sensors of pathogen_associated DNA': 'R_HSA_1834949',
#   'Cytosolic sulfonation of small molecules': 'R_HSA_156584',
#   'Cytosolic tRNA aminoacylation': 'R_HSA_379716',
#   'DAG and IP3 signaling': 'R_HSA_1489509',
#   'DARPP_32 events': 'R_HSA_180024',
#   'DNA Damage Bypass': 'R_HSA_73893',
#   'DNA Damage Recognition in GG_NER': 'R_HSA_5696394',
#   'DNA DamageslashTelomere Stress Induced Senescence': 'R_HSA_2559586',
#   'DNA Double Strand Break Response': 'R_HSA_5693606',
#   'DNA Replication Pre_Initiation': 'R_HSA_69002',
#   'DNA methylation': 'R_HSA_5334118',
#   'DNA strand elongation': 'R_HSA_69190',
#   'Deactivation of the beta_catenin transactivating complex': 'R_HSA_3769402',
#   'Deadenylation of mRNA': 'R_HSA_429947',
#   'Deadenylation_dependent mRNA decay': 'R_HSA_429914',
#   'Death Receptor Signalling': 'R_HSA_73887',
#   'Dectin_1 mediated noncanonical NF_kB signaling': 'R_HSA_5607761',
#   'Defective B3GALT6 causes EDSP2 and SEMDJL1': 'R_HSA_4420332',
#   'Defective B3GALTL causes Peters_plus syndrome PpS': 'R_HSA_5083635',
#   'Defective B3GAT3 causes JDSSDHD': 'R_HSA_3560801',
#   'Defective B4GALT7 causes EDS progeroid type': 'R_HSA_3560783',
#   'Defective C1GALT1C1 causes Tn polyagglutination syndrome TNPS': 'R_HSA_5083632',
#   'Defective GALNT12 causes colorectal cancer 1 CRCS1': 'R_HSA_5083636',
#   'Defective GALNT3 causes familial hyperphosphatemic tumoral calcinosis HFTC': 'R_HSA_5083625',
#   'Defects in vitamin and cofactor metabolism': 'R_HSA_3296482',
#   'Defensins': 'R_HSA_1461973',
#   'Degradation of AXIN': 'R_HSA_4641257',
#   'Degradation of DVL': 'R_HSA_4641258',
#   'Degradation of GLI1 by the proteasome': 'R_HSA_5610780',
#   'Degradation of GLI2 by the proteasome': 'R_HSA_5610783',
#   'Degradation of beta_catenin by the destruction complex': 'R_HSA_195253',
#   'Depolymerisation of the Nuclear Lamina': 'R_HSA_4419969',
#   'Deposition of new CENPA_containing nucleosomes at the centromere': 'R_HSA_606279',
#   'Detoxification of Reactive Oxygen Species': 'R_HSA_3299685',
#   'Digestion of dietary lipid': 'R_HSA_192456',
#   'Disassembly of the destruction complex and recruitment of AXIN to the membrane': 'R_HSA_4641262',
#   'Diseases associated with O_glycosylation of proteins': 'R_HSA_3906995',
#   'Diseases associated with glycosaminoglycan metabolism': 'R_HSA_3560782',
#   'Diseases associated with the TLR signaling cascade': 'R_HSA_5602358',
#   'Diseases of Immune System': 'R_HSA_5260271',
#   'Diseases of glycosylation': 'R_HSA_3781865',
#   'Diseases of metabolism': 'R_HSA_5668914',
#   'Disorders of transmembrane transporters': 'R_HSA_5619115',
#   'Dopamine Neurotransmitter Release Cycle': 'R_HSA_212676',
#   'Downregulation of SMAD2slash3:SMAD4 transcriptional activity': 'R_HSA_2173795',
#   'Downregulation of TGF_beta receptor signaling': 'R_HSA_2173788',
#   'Downstream TCR signaling': 'R_HSA_202424',
#   'Dual Incision in GG_NER': 'R_HSA_5696400',
#   'Dual incision in TC_NER': 'R_HSA_6782135',
#   'E2F mediated regulation of DNA replication': 'R_HSA_113510',
#   'ECM proteoglycans': 'R_HSA_3000178',
#   'EGFR downregulation': 'R_HSA_182971',
#   'EGFR interacts with phospholipase C_gamma': 'R_HSA_212718',
#   'EPHA_mediated growth cone collapse': 'R_HSA_3928663',
#   'EPHB_mediated forward signaling': 'R_HSA_3928662',
#   'EPH_Ephrin signaling': 'R_HSA_2682334',
#   'EPH_ephrin mediated repulsion of cells': 'R_HSA_3928665',
#   'ERBB2 Regulates Cell Motility': 'R_HSA_6785631',
#   'ERCC6 CSB and EHMT2 G9a positively regulate rRNA expression': 'R_HSA_427389',
#   'ERKslashMAPK targets': 'R_HSA_198753',
#   'ER_Phagosome pathway': 'R_HSA_1236974',
#   'Effects of PIP2 hydrolysis': 'R_HSA_114508',
#   'Eicosanoid ligand_binding receptors': 'R_HSA_391903',
#   'Elastic fibre formation': 'R_HSA_1566948',
#   'Elevation of cytosolic Ca2+ levels': 'R_HSA_139853',
#   'Elongation arrest and recovery': 'R_HSA_112387',
#   'Endogenous sterols': 'R_HSA_211976',
#   'Endosomal Sorting Complex Required For Transport ESCRT': 'R_HSA_917729',
#   'Energy dependent regulation of mTOR by LKB1_AMPK': 'R_HSA_380972',
#   'Ephrin signaling': 'R_HSA_3928664',
#   'Eukaryotic Translation Elongation': 'R_HSA_156842',
#   'Eukaryotic Translation Termination': 'R_HSA_72764',
#   'Export of Viral Ribonucleoproteins from Nucleus': 'R_HSA_168274',
#   'Extension of Telomeres': 'R_HSA_180786',
#   'FCERI mediated Ca+2 mobilization': 'R_HSA_2871809',
#   'FCGR activation': 'R_HSA_2029481',
#   'FGFR1 ligand binding and activation': 'R_HSA_190242',
#   'FGFR1 mutant receptor activation': 'R_HSA_1839124',
#   'FGFR2 alternative splicing': 'R_HSA_6803529',
#   'FGFR2 ligand binding and activation': 'R_HSA_190241',
#   'FGFR2 mutant receptor activation': 'R_HSA_1839126',
#   'Fanconi Anemia Pathway': 'R_HSA_6783310',
#   'Fatty Acyl_CoA Biosynthesis': 'R_HSA_75105',
#   'Fatty acids': 'R_HSA_211935',
#   'Fertilization': 'R_HSA_1187000',
#   'Formation of ATP by chemiosmotic coupling': 'R_HSA_163210',
#   'Formation of Fibrin Clot Clotting Cascade': 'R_HSA_140877',
#   'Formation of HIV elongation complex in the absence of HIV Tat': 'R_HSA_167152',
#   'Formation of HIV_1 elongation complex containing HIV_1 Tat': 'R_HSA_167200',
#   'Formation of Incision Complex in GG_NER': 'R_HSA_5696395',
#   'Formation of RNA Pol II elongation complex': 'R_HSA_112382',
#   'Formation of Senescence_Associated Heterochromatin Foci SAHF': 'R_HSA_2559584',
#   'Formation of TC_NER Pre_Incision Complex': 'R_HSA_6781823',
#   'Formation of a pool of free 40S subunits': 'R_HSA_72689',
#   'Formation of the Early Elongation Complex': 'R_HSA_113418',
#   'Formation of the HIV_1 Early Elongation Complex': 'R_HSA_167158',
#   'Formation of the beta_catenin:TCF transactivating complex': 'R_HSA_201722',
#   'Formation of the ternary complex and subsequently the 43S complex': 'R_HSA_72695',
#   'Formation of tubulin folding intermediates by CCTslashTriC': 'R_HSA_389960',
#   'G alpha 12slash13 signalling events': 'R_HSA_416482',
#   'G alpha z signalling events': 'R_HSA_418597',
#   'G beta:gamma signalling through PI3Kgamma': 'R_HSA_392451',
#   'G beta:gamma signalling through PLC beta': 'R_HSA_418217',
#   'G protein gated Potassium channels': 'R_HSA_1296059',
#   'G0 and Early G1': 'R_HSA_1538133',
#   'G1 Phase': 'R_HSA_69236',
#   'G1slashS DNA Damage Checkpoints': 'R_HSA_69615',
#   'G1slashS_Specific Transcription': 'R_HSA_69205',
#   'G2slashM DNA damage checkpoint': 'R_HSA_69473',
#   'GABA B receptor activation': 'R_HSA_977444',
#   'GABA receptor activation': 'R_HSA_977443',
#   'GABA synthesis release reuptake and degradation': 'R_HSA_888590',
#   'GLI3 is processed to GLI3R by the proteasome': 'R_HSA_5610785',
#   'GPVI_mediated activation cascade': 'R_HSA_114604',
#   'GRB2 events in ERBB2 signaling': 'R_HSA_1963640',
#   'GRB2:SOS provides linkage to MAPK signaling for Integrins': 'R_HSA_354194',
#   'G_protein activation': 'R_HSA_202040',
#   'G_protein beta:gamma signalling': 'R_HSA_397795',
#   'G_protein mediated events': 'R_HSA_112040',
#   'Gamma carboxylation hypusine formation and arylsulfatase activation': 'R_HSA_163841',
#   'Gap junction assembly': 'R_HSA_190861',
#   'Gap junction trafficking': 'R_HSA_190828',
#   'Gap junction trafficking and regulation': 'R_HSA_157858',
#   'Gap_filling DNA repair synthesis and ligation in GG_NER': 'R_HSA_5696397',
#   'Gap_filling DNA repair synthesis and ligation in TC_NER': 'R_HSA_6782210',
#   'Generation of second messenger molecules': 'R_HSA_202433',
#   'Global Genome Nucleotide Excision Repair GG_NER': 'R_HSA_5696399',
#   'Glucagon signaling in metabolic regulation': 'R_HSA_163359',
#   'Glucagon_like Peptide_1 GLP1 regulates insulin secretion': 'R_HSA_381676',
#   'Glucagon_type ligand receptors': 'R_HSA_420092',
#   'Gluconeogenesis': 'R_HSA_70263',
#   'Glucose metabolism': 'R_HSA_70326',
#   'Glucose transport': 'R_HSA_70153',
#   'Glucuronidation': 'R_HSA_156588',
#   'Glutamate Binding Activation of AMPA Receptors and Synaptic Plasticity': 'R_HSA_399721',
#   'Glutamate Neurotransmitter Release Cycle': 'R_HSA_210500',
#   'Glutathione conjugation': 'R_HSA_156590',
#   'Glycogen breakdown glycogenolysis': 'R_HSA_70221',
#   'Glycogen synthesis': 'R_HSA_3322077',
#   'Glycolysis': 'R_HSA_70171',
#   'Glycosphingolipid metabolism': 'R_HSA_1660662',
#   'Glyoxylate metabolism and glycine degradation': 'R_HSA_389661',
#   'Golgi Associated Vesicle Biogenesis': 'R_HSA_432722',
#   'Growth hormone receptor signaling': 'R_HSA_982772',
#   'HDACs deacetylate histones': 'R_HSA_3214815',
#   'HDL_mediated lipid transport': 'R_HSA_194223',
#   'HDMs demethylate histones': 'R_HSA_3214842',
#   'HDR through Homologous Recombination HRR': 'R_HSA_5685942',
#   'HDR through Single Strand Annealing SSA': 'R_HSA_5685938',
#   'HIV Transcription Elongation': 'R_HSA_167169',
#   'HIV Transcription Initiation': 'R_HSA_167161',
#   'HIV elongation arrest and recovery': 'R_HSA_167287',
#   'HSF1 activation': 'R_HSA_3371511',
#   'HSF1_dependent transactivation': 'R_HSA_3371571',
#   'HS_GAG biosynthesis': 'R_HSA_2022928',
#   'HS_GAG degradation': 'R_HSA_2024096',
#   'Hedgehog  off  state': 'R_HSA_5610787',
#   'Hedgehog  on  state': 'R_HSA_5632684',
#   'Hedgehog ligand biogenesis': 'R_HSA_5358346',
#   'Heparan sulfateslashheparin HS_GAG metabolism': 'R_HSA_1638091',
#   'Hexose transport': 'R_HSA_189200',
#   'Hh mutants abrogate ligand secretion': 'R_HSA_5387390',
#   'Hh mutants that don t undergo autocatalytic processing are degraded by ERAD': 'R_HSA_5362768',
#   'Histidine lysine phenylalanine tyrosine proline and tryptophan catabolism': 'R_HSA_6788656',
#   'Homologous DNA Pairing and Strand Exchange': 'R_HSA_5693579',
#   'Hormone_sensitive lipase HSL_mediated triacylglycerol hydrolysis': 'R_HSA_163560',
#   'Host Interactions with Influenza Factors': 'R_HSA_168253',
#   'Hyaluronan metabolism': 'R_HSA_2142845',
#   'IKK complex recruitment mediated by RIP1': 'R_HSA_937041',
#   'IL_6_type cytokine receptor ligand interactions': 'R_HSA_6788467',
#   'IRE1alpha activates chaperones': 'R_HSA_381070',
#   'ISG15 antiviral mechanism': 'R_HSA_1169408',
#   'Inactivation of APCslashC via direct inhibition of the APCslashC complex': 'R_HSA_141430',
#   'Inactivation recovery and regulation of the phototransduction cascade': 'R_HSA_2514859',
#   'Incretin synthesis secretion and inactivation': 'R_HSA_400508',
#   'Inflammasomes': 'R_HSA_622312',
#   'Inhibition  of voltage gated Ca2+ channels via Gbetaslashgamma subunits': 'R_HSA_997272',
#   'Inhibition of the proteolytic activity of APCslashC required for the onset of anaphase by mitotic spindle checkpoint components': 'R_HSA_141405',
#   'Initial triggering of complement': 'R_HSA_166663',
#   'Inositol phosphate metabolism': 'R_HSA_1483249',
#   'Insulin processing': 'R_HSA_264876',
#   'Insulin receptor recycling': 'R_HSA_77387',
#   'Integrin alphaIIb beta3 signaling': 'R_HSA_354192',
#   'Integrin cell surface interactions': 'R_HSA_216083',
#   'Interaction between L1 and Ankyrins': 'R_HSA_445095',
#   'Interactions of Rev with host cellular proteins': 'R_HSA_177243',
#   'Interactions of Vpr with host cellular proteins': 'R_HSA_176033',
#   'Interferon alphaslashbeta signaling': 'R_HSA_909733',
#   'Interferon gamma signaling': 'R_HSA_877300',
#   'Interleukin_1 signaling': 'R_HSA_446652',
#   'Interleukin_6 family signaling': 'R_HSA_6783589',
#   'Intra_Golgi traffic': 'R_HSA_6811438',
#   'Intraflagellar transport': 'R_HSA_5620924',
#   'Intrinsic Pathway for Apoptosis': 'R_HSA_109606',
#   'Intrinsic Pathway of Fibrin Clot Formation': 'R_HSA_140837',
#   'Inwardly rectifying K+ channels': 'R_HSA_1296065',
#   'Ion homeostasis': 'R_HSA_5578775',
#   'Ion transport by P_type ATPases': 'R_HSA_936837',
#   'Iron uptake and transport': 'R_HSA_917937',
#   'JNK c_Jun kinases phosphorylation and  activation mediated by activated human TAK1': 'R_HSA_450321',
#   'KSRP KHSRP binds and destabilizes mRNA': 'R_HSA_450604',
#   'Keratan sulfate biosynthesis': 'R_HSA_2022854',
#   'Keratan sulfateslashkeratin metabolism': 'R_HSA_1638074',
#   'Kinesins': 'R_HSA_983189',
#   'L1CAM interactions': 'R_HSA_373760',
#   'Lagging Strand Synthesis': 'R_HSA_69186',
#   'Laminin interactions': 'R_HSA_3000157',
#   'Ligand_dependent caspase activation': 'R_HSA_140534',
#   'Ligand_gated ion channel transport': 'R_HSA_975298',
#   'Lipid digestion mobilization and transport': 'R_HSA_73923',
#   'Lipoprotein metabolism': 'R_HSA_174824',
#   'Loss of Nlp from mitotic centrosomes': 'R_HSA_380259',
#   'Loss of proteins required for interphase microtubule organization\xa0from the centrosome': 'R_HSA_380284',
#   'Lysosome Vesicle Biogenesis': 'R_HSA_432720',
#   'MAP kinase activation in TLR cascade': 'R_HSA_450294',
#   'MAP2K and MAPK activation': 'R_HSA_5674135',
#   'MAP3K8 TPL2_dependent MAPK1slash3 activation': 'R_HSA_5684264',
#   'MAPK targetsslash Nuclear events mediated by MAP kinases': 'R_HSA_450282',
#   'MAPK6slashMAPK4 signaling': 'R_HSA_5687128',
#   'Macroautophagy': 'R_HSA_1632852',
#   'Meiosis': 'R_HSA_1500620',
#   'Meiotic recombination': 'R_HSA_912446',
#   'Meiotic synapsis': 'R_HSA_1221632',
#   'Metabolism of Angiotensinogen to Angiotensins': 'R_HSA_2022377',
#   'Metabolism of fat_soluble vitamins': 'R_HSA_6806667',
#   'Metabolism of folate and pterines': 'R_HSA_196757',
#   'Metabolism of nitric oxide': 'R_HSA_202131',
#   'Metabolism of non_coding RNA': 'R_HSA_194441',
#   'Metabolism of nucleotides': 'R_HSA_15869',
#   'Metabolism of polyamines': 'R_HSA_351202',
#   'Metabolism of porphyrins': 'R_HSA_189445',
#   'Metabolism of steroid hormones': 'R_HSA_196071',
#   'Metabolism of water_soluble vitamins and cofactors': 'R_HSA_196849',
#   'Metal ion SLC transporters': 'R_HSA_425410',
#   'MicroRNA miRNA biogenesis': 'R_HSA_203927',
#   'Miscellaneous transport and binding events': 'R_HSA_5223345',
#   'Mismatch Repair': 'R_HSA_5358508',
#   'Misspliced GSK3beta mutants stabilize beta_catenin': 'R_HSA_5339716',
#   'Mitochondrial Fatty Acid Beta_Oxidation': 'R_HSA_77289',
#   'Mitochondrial biogenesis': 'R_HSA_1592230',
#   'Mitochondrial protein import': 'R_HSA_1268020',
#   'Mitochondrial tRNA aminoacylation': 'R_HSA_379726',
#   'Mitochondrial translation': 'R_HSA_5368287',
#   'Mitochondrial translation elongation': 'R_HSA_5389840',
#   'Mitochondrial translation initiation': 'R_HSA_5368286',
#   'Mitochondrial translation termination': 'R_HSA_5419276',
#   'Mitophagy': 'R_HSA_5205647',
#   'Mitotic Spindle Checkpoint': 'R_HSA_69618',
#   'Molecules associated with elastic fibres': 'R_HSA_2129379',
#   'MslashG1 Transition': 'R_HSA_68874',
#   'MyD88 cascade initiated on plasma membrane': 'R_HSA_975871',
#   'MyD88 dependent cascade initiated on endosome': 'R_HSA_975155',
#   'MyD88:Mal cascade initiated on plasma membrane': 'R_HSA_166058',
#   'MyD88_independent TLR3slashTLR4 cascade': 'R_HSA_166166',
#   'Myogenesis': 'R_HSA_525793',
#   'NCAM1 interactions': 'R_HSA_419037',
#   'NEPslashNS2 Interacts with the Cellular Export Machinery': 'R_HSA_168333',
#   'NIK__>noncanonical NF_kB signaling': 'R_HSA_5676590',
#   'NOD1slash2 Signaling Pathway': 'R_HSA_168638',
#   'NOTCH1 Intracellular Domain Regulates Transcription': 'R_HSA_2122947',
#   'NOTCH2 Activation and Transmission of Signal to the Nucleus': 'R_HSA_2979096',
#   'NRAGE signals death through JNK': 'R_HSA_193648',
#   'NRIF signals cell death from the nucleus': 'R_HSA_205043',
#   'NS1 Mediated Effects on Host Pathways': 'R_HSA_168276',
#   'N_Glycan antennae elongation': 'R_HSA_975577',
#   'N_glycan antennae elongation in the medialslashtrans_Golgi': 'R_HSA_975576',
#   'N_glycan trimming in the ER and CalnexinslashCalreticulin cycle': 'R_HSA_532668',
#   'Na+slashCl_ dependent neurotransmitter transporters': 'R_HSA_442660',
#   'Nef_mediates down modulation of cell surface receptors by recruiting them to clathrin adapters': 'R_HSA_164938',
#   'Negative epigenetic regulation of rRNA expression': 'R_HSA_5250941',
#   'Negative regulation of FGFR1 signaling': 'R_HSA_5654726',
#   'Negative regulation of FGFR2 signaling': 'R_HSA_5654727',
#   'Negative regulation of FGFR3 signaling': 'R_HSA_5654732',
#   'Negative regulation of FGFR4 signaling': 'R_HSA_5654733',
#   'Negative regulation of MAPK pathway': 'R_HSA_5675221',
#   'Negative regulation of TCF_dependent signaling by WNT ligand antagonists': 'R_HSA_3772470',
#   'Negative regulation of the PI3KslashAKT network': 'R_HSA_199418',
#   'Negative regulators of RIG_IslashMDA5 signaling': 'R_HSA_936440',
#   'Nephrin interactions': 'R_HSA_373753',
#   'Netrin_1 signaling': 'R_HSA_373752',
#   'Neurotransmitter Release Cycle': 'R_HSA_112310',
#   'Nitric oxide stimulates guanylate cyclase': 'R_HSA_392154',
#   'NoRC negatively regulates rRNA expression': 'R_HSA_427413',
#   'Non_integrin membrane_ECM interactions': 'R_HSA_3000171',
#   'Nonhomologous End_Joining NHEJ': 'R_HSA_5693571',
#   'Nonsense Mediated Decay NMD independent of the Exon Junction Complex EJC': 'R_HSA_975956',
#   'Norepinephrine Neurotransmitter Release Cycle': 'R_HSA_181430',
#   'Nuclear Envelope Breakdown': 'R_HSA_2980766',
#   'Nuclear Events kinase and transcription factor activation': 'R_HSA_198725',
#   'Nuclear Pore Complex NPC Disassembly': 'R_HSA_3301854',
#   'Nuclear Receptor transcription pathway': 'R_HSA_383280',
#   'Nuclear import of Rev protein': 'R_HSA_180746',
#   'Nuclear signaling by ERBB4': 'R_HSA_1251985',
#   'Nucleosome assembly': 'R_HSA_774815',
#   'Nucleotide_binding domain leucine rich repeat containing receptor NLR signaling pathways': 'R_HSA_168643',
#   'Nucleotide_like purinergic receptors': 'R_HSA_418038',
#   'O_glycosylation of TSR domain_containing proteins': 'R_HSA_5173214',
#   'O_linked glycosylation of mucins': 'R_HSA_913709',
#   'Oncogene Induced Senescence': 'R_HSA_2559585',
#   'Opioid Signalling': 'R_HSA_111885',
#   'Orc1 removal from chromatin': 'R_HSA_68949',
#   'Other semaphorin interactions': 'R_HSA_416700',
#   'Oxidative Stress Induced Senescence': 'R_HSA_2559580',
#   'Oxygen_dependent proline hydroxylation of Hypoxia_inducible Factor Alpha': 'R_HSA_1234176',
#   'PCNA_Dependent Long Patch Base Excision Repair': 'R_HSA_5651801',
#   'PCPslashCE pathway': 'R_HSA_4086400',
#   'PD_1 signaling': 'R_HSA_389948',
#   'PERK regulates gene expression': 'R_HSA_381042',
#   'PI Metabolism': 'R_HSA_1483255',
#   'PI3K Cascade': 'R_HSA_109704',
#   'PI3K events in ERBB2 signaling': 'R_HSA_1963642',
#   'PI3KslashAKT Signaling in Cancer': 'R_HSA_2219528',
#   'PI5P PP2A and IER3 Regulate PI3KslashAKT Signaling': 'R_HSA_6811558',
#   'PIWI_interacting RNA piRNA biogenesis': 'R_HSA_5601884',
#   'PKA activation': 'R_HSA_163615',
#   'PKA activation in glucagon signalling': 'R_HSA_164378',
#   'PKA_mediated phosphorylation of CREB': 'R_HSA_111931',
#   'PKB_mediated events': 'R_HSA_109703',
#   'PKMTs methylate histone lysines': 'R_HSA_3214841',
#   'PLC beta mediated events': 'R_HSA_112043',
#   'PLC_gamma1 signalling': 'R_HSA_167021',
#   'PRC2 methylates histones and DNA': 'R_HSA_212300',
#   'PTK6 Regulates RHO GTPases RAS GTPase and MAP kinases': 'R_HSA_8849471',
#   'Packaging Of Telomere Ends': 'R_HSA_171306',
#   'Pausing and recovery of HIV elongation': 'R_HSA_167290',
#   'Pausing and recovery of Tat_mediated HIV elongation': 'R_HSA_167238',
#   'Peptide chain elongation': 'R_HSA_156902',
#   'Peptide hormone metabolism': 'R_HSA_2980736',
#   'Peroxisomal lipid metabolism': 'R_HSA_390918',
#   'Phase 0 _ rapid depolarisation': 'R_HSA_5576892',
#   'Phase 1 _ Functionalization of compounds': 'R_HSA_211945',
#   'Phase 1 _ inactivation of fast Na+ channels': 'R_HSA_5576894',
#   'Phase 2 _ plateau phase': 'R_HSA_5576893',
#   'Phase 4 _ resting membrane potential': 'R_HSA_5576886',
#   'Phospholipase C_mediated cascade FGFR2': 'R_HSA_5654221',
#   'Phospholipase C_mediated cascade FGFR3': 'R_HSA_5654227',
#   'Phospholipase C_mediated cascade FGFR4': 'R_HSA_5654228',
#   'Phospholipase C_mediated cascade: FGFR1': 'R_HSA_5654219',
#   'Phosphorylation of CD3 and TCR zeta chains': 'R_HSA_202427',
#   'Phosphorylation of the APCslashC': 'R_HSA_176412',
#   'PinkslashParkin Mediated Mitophagy': 'R_HSA_5205685',
#   'Platelet Aggregation Plug Formation': 'R_HSA_76009',
#   'Platelet calcium homeostasis': 'R_HSA_418360',
#   'Platelet homeostasis': 'R_HSA_418346',
#   'Platelet sensitization by LDL': 'R_HSA_432142',
#   'Polo_like kinase mediated events': 'R_HSA_156711',
#   'Positive epigenetic regulation of rRNA expression': 'R_HSA_5250913',
#   'Post NMDA receptor activation events': 'R_HSA_438064',
#   'Post_Elongation Processing of Intron_Containing pre_mRNA': 'R_HSA_112296',
#   'Post_Elongation Processing of Intronless pre_mRNA': 'R_HSA_112297',
#   'Post_Elongation Processing of the Transcript': 'R_HSA_76044',
#   'Post_chaperonin tubulin folding pathway': 'R_HSA_389977',
#   'Post_translational modification: synthesis of GPI_anchored proteins': 'R_HSA_163125',
#   'Potassium Channels': 'R_HSA_1296071',
#   'Pre_NOTCH Expression and Processing': 'R_HSA_1912422',
#   'Pre_NOTCH Processing in Golgi': 'R_HSA_1912420',
#   'Pre_NOTCH Transcription and Translation': 'R_HSA_1912408',
#   'Prefoldin mediated transfer of substrate  to CCTslashTriC': 'R_HSA_389957',
#   'Presynaptic function of Kainate receptors': 'R_HSA_500657',
#   'Presynaptic phase of homologous DNA pairing and strand exchange': 'R_HSA_5693616',
#   'Processing of Capped Intronless Pre_mRNA': 'R_HSA_75067',
#   'Processing of DNA double_strand break ends': 'R_HSA_5693607',
#   'Processing of Intronless Pre_mRNAs': 'R_HSA_77595',
#   'Processive synthesis on the lagging strand': 'R_HSA_69183',
#   'Prolactin receptor signaling': 'R_HSA_1170546',
#   'Prostacyclin signalling through prostacyclin receptor': 'R_HSA_392851',
#   'Purine metabolism': 'R_HSA_73847',
#   'Pyrimidine metabolism': 'R_HSA_73848',
#   'Pyruvate metabolism': 'R_HSA_70268',
#   'Pyruvate metabolism and Citric Acid TCA cycle': 'R_HSA_71406',
#   'RA biosynthesis pathway': 'R_HSA_5365859',
#   'RAF activation': 'R_HSA_5673000',
#   'RAF_independent MAPK1slash3 activation': 'R_HSA_112409',
#   'RHO GTPases Activate ROCKs': 'R_HSA_5627117',
#   'RHO GTPases Activate WASPs and WAVEs': 'R_HSA_5663213',
#   'RHO GTPases activate CIT': 'R_HSA_5625900',
#   'RHO GTPases activate PAKs': 'R_HSA_5627123',
#   'RHO GTPases activate PKNs': 'R_HSA_5625740',
#   'RIG_IslashMDA5 mediated induction of IFN_alphaslashbeta pathways': 'R_HSA_168928',
#   'RIPK1_mediated regulated necrosis': 'R_HSA_5213460',
#   'RIP_mediated NFkB activation via ZBP1': 'R_HSA_1810476',
#   'RMTs methylate histone arginines': 'R_HSA_3214858',
#   'RNA Pol II CTD phosphorylation and interaction with CE': 'R_HSA_77075',
#   'RNA Polymerase I Chain Elongation': 'R_HSA_73777',
#   'RNA Polymerase I Promoter Clearance': 'R_HSA_73854',
#   'RNA Polymerase I Promoter Escape': 'R_HSA_73772',
#   'RNA Polymerase I Promoter Opening': 'R_HSA_73728',
#   'RNA Polymerase I Transcription': 'R_HSA_73864',
#   'RNA Polymerase I Transcription Initiation': 'R_HSA_73762',
#   'RNA Polymerase I Transcription Termination': 'R_HSA_73863',
#   'RNA Polymerase II HIV Promoter Escape': 'R_HSA_167162',
#   'RNA Polymerase II Pre_transcription Events': 'R_HSA_674695',
#   'RNA Polymerase II Promoter Escape': 'R_HSA_73776',
#   'RNA Polymerase II Transcription Elongation': 'R_HSA_75955',
#   'RNA Polymerase II Transcription Initiation': 'R_HSA_75953',
#   'RNA Polymerase II Transcription Initiation And Promoter Clearance': 'R_HSA_76042',
#   'RNA Polymerase II Transcription Pre_Initiation And Promoter Opening': 'R_HSA_73779',
#   'RNA Polymerase II Transcription Termination': 'R_HSA_73856',
#   'RNA Polymerase III Abortive And Retractive Initiation': 'R_HSA_749476',
#   'RNA Polymerase III Chain Elongation': 'R_HSA_73780',
#   'RNA Polymerase III Transcription': 'R_HSA_74158',
#   'RNA Polymerase III Transcription Initiation': 'R_HSA_76046',
#   'RNA Polymerase III Transcription Initiation From Type 1 Promoter': 'R_HSA_76061',
#   'RNA Polymerase III Transcription Initiation From Type 2 Promoter': 'R_HSA_76066',
#   'RNA Polymerase III Transcription Initiation From Type 3 Promoter': 'R_HSA_76071',
#   'RNA Polymerase III Transcription Termination': 'R_HSA_73980',
#   'RNA polymerase II transcribes snRNA genes': 'R_HSA_6807505',
#   'RORA activates gene expression': 'R_HSA_1368082',
#   'ROS RNS production in response to bacteria': 'R_HSA_1222556',
#   'Rap1 signalling': 'R_HSA_392517',
#   'Ras activation uopn Ca2+ infux through NMDA receptor': 'R_HSA_442982',
#   'Recognition of DNA damage by PCNA_containing replication complex': 'R_HSA_110314',
#   'Recruitment and ATM_mediated phosphorylation of repair and signaling proteins at DNA double strand breaks': 'R_HSA_5693565',
#   'Recruitment of mitotic centrosome proteins and complexes': 'R_HSA_380270',
#   'Recycling of bile acids and salts': 'R_HSA_159418',
#   'Recycling pathway of L1': 'R_HSA_437239',
#   'Regulated Necrosis': 'R_HSA_5218859',
#   'Regulation of APCslashC activators between G1slashS and early anaphase': 'R_HSA_176408',
#   'Regulation of Apoptosis': 'R_HSA_169911',
#   'Regulation of Complement cascade': 'R_HSA_977606',
#   'Regulation of DNA replication': 'R_HSA_69304',
#   'Regulation of FZD by ubiquitination': 'R_HSA_4641263',
#   'Regulation of Glucokinase by Glucokinase Regulatory Protein': 'R_HSA_170822',
#   'Regulation of HSF1_mediated heat shock response': 'R_HSA_3371453',
#   'Regulation of Hypoxia_inducible Factor HIF by oxygen': 'R_HSA_1234174',
#   'Regulation of IFNA signaling': 'R_HSA_912694',
#   'Regulation of Insulin_like Growth Factor IGF transport and uptake by Insulin_like Growth Factor Binding Proteins IGFBPs': 'R_HSA_381426',
#   'Regulation of KIT signaling': 'R_HSA_1433559',
#   'Regulation of PLK1 Activity at G2slashM Transition': 'R_HSA_2565942',
#   'Regulation of RAS by GAPs': 'R_HSA_5658442',
#   'Regulation of TNFR1 signaling': 'R_HSA_5357905',
#   'Regulation of TP53 Activity through Acetylation': 'R_HSA_6804758',
#   'Regulation of TP53 Activity through Methylation': 'R_HSA_6804760',
#   'Regulation of TP53 Activity through Phosphorylation': 'R_HSA_6804756',
#   'Regulation of TP53 Degradation': 'R_HSA_6804757',
#   'Regulation of TP53 Expression and Degradation': 'R_HSA_6806003',
#   'Regulation of actin dynamics for phagocytic cup formation': 'R_HSA_2029482',
#   'Regulation of activated PAK_2p34 by proteasome mediated degradation': 'R_HSA_211733',
#   'Regulation of beta_cell development': 'R_HSA_186712',
#   'Regulation of cholesterol biosynthesis by SREBP SREBF': 'R_HSA_1655829',
#   'Regulation of gene expression in beta cells': 'R_HSA_210745',
#   'Regulation of innate immune responses to cytosolic DNA': 'R_HSA_3134975',
#   'Regulation of insulin secretion': 'R_HSA_422356',
#   'Regulation of mRNA stability by proteins that bind AU_rich elements': 'R_HSA_450531',
#   'Regulation of mitotic cell cycle': 'R_HSA_453276',
#   'Regulation of ornithine decarboxylase ODC': 'R_HSA_350562',
#   'Regulation of signaling by CBL': 'R_HSA_912631',
#   'Removal of licensing factors from origins': 'R_HSA_69300',
#   'Reproduction': 'R_HSA_1474165',
#   'Resolution of AP sites via the multiple_nucleotide patch replacement pathway': 'R_HSA_110373',
#   'Resolution of Abasic Sites AP sites': 'R_HSA_73933',
#   'Resolution of D_Loop Structures': 'R_HSA_5693537',
#   'Resolution of D_loop Structures through Holliday Junction Intermediates': 'R_HSA_5693568',
#   'Resolution of D_loop Structures through Synthesis_Dependent Strand Annealing SDSA': 'R_HSA_5693554',
#   'Resolution of Sister Chromatid Cohesion': 'R_HSA_2500257',
#   'Respiratory electron transport': 'R_HSA_611105',
#   'Retinoid metabolism and transport': 'R_HSA_975634',
#   'Retrograde transport at the Trans_Golgi_Network': 'R_HSA_6811440',
#   'Rev_mediated nuclear export of HIV RNA': 'R_HSA_165054',
#   'Ribosomal scanning and start codon recognition': 'R_HSA_72702',
#   'Role of phospholipids in phagocytosis': 'R_HSA_2029485',
#   'S33 mutants of beta_catenin aren t phosphorylated': 'R_HSA_5358747',
#   'S37 mutants of beta_catenin aren t phosphorylated': 'R_HSA_5358749',
#   'S45 mutants of beta_catenin aren t phosphorylated': 'R_HSA_5358751',
#   'SALM protein interactions at the synapse': 'R_HSA_8849932',
#   'SCFSkp2_mediated degradation of p27slashp21': 'R_HSA_187577',
#   'SCF_beta_TrCP mediated degradation of Emi1': 'R_HSA_174113',
#   'SHC1 events in ERBB2 signaling': 'R_HSA_1250196',
#   'SHC_mediated cascade:FGFR1': 'R_HSA_5654688',
#   'SHC_mediated cascade:FGFR2': 'R_HSA_5654699',
#   'SHC_mediated cascade:FGFR3': 'R_HSA_5654704',
#   'SHC_mediated cascade:FGFR4': 'R_HSA_5654719',
#   'SIRT1 negatively regulates rRNA Expression': 'R_HSA_427359',
#   'SMAD2slashSMAD3:SMAD4 heterotrimer regulates transcription': 'R_HSA_2173796',
#   'STING mediated induction of host immune responses': 'R_HSA_1834941',
#   'SUMO E3 ligases SUMOylate target proteins': 'R_HSA_3108232',
#   'SUMOylation of DNA damage response and repair proteins': 'R_HSA_3108214',
#   'SUMOylation of DNA replication proteins': 'R_HSA_4615885',
#   'SUMOylation of RNA binding proteins': 'R_HSA_4570464',
#   'Scavenging by Class A Receptors': 'R_HSA_3000480',
#   'Scavenging of heme from plasma': 'R_HSA_2168880',
#   'Selenocysteine synthesis': 'R_HSA_2408557',
#   'Sema3A PAK dependent Axon repulsion': 'R_HSA_399954',
#   'Sema4D in semaphorin signaling': 'R_HSA_400685',
#   'Sema4D induced cell migration and growth_cone collapse': 'R_HSA_416572',
#   'Semaphorin interactions': 'R_HSA_373755',
#   'Senescence_Associated Secretory Phenotype SASP': 'R_HSA_2559582',
#   'Serotonin Neurotransmitter Release Cycle': 'R_HSA_181429',
#   'Sialic acid metabolism': 'R_HSA_4085001',
#   'Signal amplification': 'R_HSA_392518',
#   'Signal transduction by L1': 'R_HSA_445144',
#   'Signaling by BMP': 'R_HSA_201451',
#   'Signaling by EGFR in Cancer': 'R_HSA_1643713',
#   'Signaling by EGFRvIII in Cancer': 'R_HSA_5637812',
#   'Signaling by ERBB2': 'R_HSA_1227986',
#   'Signaling by FGFR in disease': 'R_HSA_1226099',
#   'Signaling by FGFR1 in disease': 'R_HSA_5655302',
#   'Signaling by FGFR2 IIIa TM': 'R_HSA_8851708',
#   'Signaling by FGFR2 in disease': 'R_HSA_5655253',
#   'Signaling by FGFR3 in disease': 'R_HSA_5655332',
#   'Signaling by FGFR3 point mutants in cancer': 'R_HSA_8853338',
#   'Signaling by Hippo': 'R_HSA_2028269',
#   'Signaling by Ligand_Responsive EGFR Variants in Cancer': 'R_HSA_5637815',
#   'Signaling by NODAL': 'R_HSA_1181150',
#   'Signaling by NOTCH1': 'R_HSA_1980143',
#   'Signaling by NOTCH1 HD Domain Mutants in Cancer': 'R_HSA_2691230',
#   'Signaling by NOTCH1 HD+PEST Domain Mutants in Cancer': 'R_HSA_2894858',
#   'Signaling by NOTCH1 PEST Domain Mutants in Cancer': 'R_HSA_2644602',
#   'Signaling by NOTCH1 in Cancer': 'R_HSA_2644603',
#   'Signaling by NOTCH2': 'R_HSA_1980145',
#   'Signaling by PTK6': 'R_HSA_8848021',
#   'Signaling by Retinoic Acid': 'R_HSA_5362517',
#   'Signaling by Robo receptor': 'R_HSA_376176',
#   'Signaling by TGF_beta Receptor Complex': 'R_HSA_170834',
#   'Signaling by WNT in cancer': 'R_HSA_4791275',
#   'Signaling by cytosolic FGFR1 fusion mutants': 'R_HSA_1839117',
#   'Smooth Muscle Contraction': 'R_HSA_445355',
#   'Sphingolipid de novo biosynthesis': 'R_HSA_1660661',
#   'Sphingolipid metabolism': 'R_HSA_428157',
#   'Spry regulation of FGF signaling': 'R_HSA_1295596',
#   'Stabilization of p53': 'R_HSA_69541',
#   'Steroid hormones': 'R_HSA_209943',
#   'Striated Muscle Contraction': 'R_HSA_390522',
#   'Sulfur amino acid metabolism': 'R_HSA_1614635',
#   'Surfactant metabolism': 'R_HSA_5683826',
#   'Switching of origins to a post_replicative state': 'R_HSA_69052',
#   'Syndecan interactions': 'R_HSA_3000170',
#   'Synthesis and interconversion of nucleotide di_ and triphosphates': 'R_HSA_499943',
#   'Synthesis of DNA': 'R_HSA_69239',
#   'Synthesis of IP3 and IP4 in the cytosol': 'R_HSA_1855204',
#   'Synthesis of Leukotrienes LT and Eoxins EX': 'R_HSA_2142691',
#   'Synthesis of PA': 'R_HSA_1483166',
#   'Synthesis of PC': 'R_HSA_1483191',
#   'Synthesis of PIPs at the Golgi membrane': 'R_HSA_1660514',
#   'Synthesis of PIPs at the plasma membrane': 'R_HSA_1660499',
#   'Synthesis of bile acids and bile salts': 'R_HSA_192105',
#   'Synthesis of bile acids and bile salts via 27_hydroxycholesterol': 'R_HSA_193807',
#   'Synthesis of bile acids and bile salts via 7alpha_hydroxycholesterol': 'R_HSA_193368',
#   'Synthesis of glycosylphosphatidylinositol GPI': 'R_HSA_162710',
#   'Synthesis of substrates in N_glycan biosythesis': 'R_HSA_446219',
#   'Synthesis of very long_chain fatty acyl_CoAs': 'R_HSA_75876',
#   'Synthesis secretion and deacylation of Ghrelin': 'R_HSA_422085',
#   'Synthesis secretion and inactivation of Glucagon_like Peptide_1 GLP_1': 'R_HSA_381771',
#   'T41 mutants of beta_catenin aren t phosphorylated': 'R_HSA_5358752',
#   'TAK1 activates NFkB by phosphorylation and activation of IKKs complex': 'R_HSA_445989',
#   'TGF_beta receptor signaling activates SMADs': 'R_HSA_2173789',
#   'TGF_beta receptor signaling in EMT epithelial to mesenchymal transition': 'R_HSA_2173791',
#   'TNF receptor superfamily TNFSF members mediating non_canonical NF_kB pathway': 'R_HSA_5676594',
#   'TNF signaling': 'R_HSA_75893',
#   'TNFR1_induced NFkappaB signaling pathway': 'R_HSA_5357956',
#   'TNFR2 non_canonical NF_kB pathway': 'R_HSA_5668541',
#   'TNFs bind their physiological receptors': 'R_HSA_5669034',
#   'TP53 Regulates Metabolic Genes': 'R_HSA_5628897',
#   'TP53 Regulates Transcription of Cell Cycle Genes': 'R_HSA_6791312',
#   'TP53 Regulates Transcription of Cell Death Genes': 'R_HSA_5633008',
#   'TP53 Regulates Transcription of DNA Repair Genes': 'R_HSA_6796648',
#   'TP53 Regulates Transcription of Genes Involved in Cytochrome C Release': 'R_HSA_6803204',
#   'TP53 Regulates Transcription of Genes Involved in G2 Cell Cycle Arrest': 'R_HSA_6804114',
#   'TP53 regulates transcription of additional cell cycle genes whose exact role in the p53 pathway remain uncertain': 'R_HSA_6804115',
#   'TRAF6 Mediated Induction of proinflammatory cytokines': 'R_HSA_168180',
#   'TRAF6 mediated IRF7 activation': 'R_HSA_933541',
#   'TRAF6 mediated NF_kB activation': 'R_HSA_933542',
#   'TRAF6 mediated induction of NFkB and MAP kinases upon TLR7slash8 or 9 activation': 'R_HSA_975138',
#   'TRAF6 mediated induction of TAK1 complex': 'R_HSA_937072',
#   'TRIF_mediated TLR3slashTLR4 signaling': 'R_HSA_937061',
#   'TRP channels': 'R_HSA_3295583',
#   'Tat_mediated HIV elongation arrest and recovery': 'R_HSA_167243',
#   'Tat_mediated elongation of the HIV_1 transcript': 'R_HSA_167246',
#   'Telomere C_strand Lagging Strand Synthesis': 'R_HSA_174417',
#   'Telomere Maintenance': 'R_HSA_157579',
#   'Termination of O_glycan biosynthesis': 'R_HSA_977068',
#   'Termination of translesion DNA synthesis': 'R_HSA_5656169',
#   'The canonical retinoid cycle in rods twilight vision': 'R_HSA_2453902',
#   'The phototransduction cascade': 'R_HSA_2514856',
#   'The role of GTSE1 in G2slashM progression after G2 checkpoint': 'R_HSA_8852276',
#   'The role of Nef in HIV_1 replication and disease pathogenesis': 'R_HSA_164952',
#   'Thrombin signalling through proteinase activated receptors PARs': 'R_HSA_456926',
#   'Thromboxane signalling through TP receptor': 'R_HSA_428930',
#   'Tie2 Signaling': 'R_HSA_210993',
#   'Tight junction interactions': 'R_HSA_420029',
#   'Toll Like Receptor 10 TLR10 Cascade': 'R_HSA_168142',
#   'Toll Like Receptor 2 TLR2 Cascade': 'R_HSA_181438',
#   'Toll Like Receptor 3 TLR3 Cascade': 'R_HSA_168164',
#   'Toll Like Receptor 5 TLR5 Cascade': 'R_HSA_168176',
#   'Toll Like Receptor 7slash8 TLR7slash8 Cascade': 'R_HSA_168181',
#   'Toll Like Receptor 9 TLR9 Cascade': 'R_HSA_168138',
#   'Toll Like Receptor TLR1:TLR2 Cascade': 'R_HSA_168179',
#   'Toll Like Receptor TLR6:TLR2 Cascade': 'R_HSA_168188',
#   'Trafficking of AMPA receptors': 'R_HSA_399719',
#   'Trafficking of GluR2_containing AMPA receptors': 'R_HSA_416993',
#   'Transcription of the HIV genome': 'R_HSA_167172',
#   'Transcription_Coupled Nucleotide Excision Repair TC_NER': 'R_HSA_6781827',
#   'Transcriptional activation of mitochondrial biogenesis': 'R_HSA_2151201',
#   'Transcriptional activity of SMAD2slashSMAD3:SMAD4 heterotrimer': 'R_HSA_2173793',
#   'Transcriptional regulation by small RNAs': 'R_HSA_5578749',
#   'Transcriptional regulation of pluripotent stem cells': 'R_HSA_452723',
#   'Transcriptional regulation of white adipocyte differentiation': 'R_HSA_381340',
#   'Transferrin endocytosis and recycling': 'R_HSA_917977',
#   'Translation initiation complex formation': 'R_HSA_72649',
#   'Translesion Synthesis by POLH': 'R_HSA_110320',
#   'Translesion synthesis by POLI': 'R_HSA_5656121',
#   'Translesion synthesis by POLK': 'R_HSA_5655862',
#   'Translesion synthesis by REV1': 'R_HSA_110312',
#   'Translesion synthesis by Y family DNA polymerases bypasses lesions on DNA template': 'R_HSA_110313',
#   'Translocation of GLUT4 to the plasma membrane': 'R_HSA_1445148',
#   'Translocation of ZAP_70 to Immunological synapse': 'R_HSA_202430',
#   'Transport of Mature Transcript to Cytoplasm': 'R_HSA_72202',
#   'Transport of Mature mRNA Derived from an Intronless Transcript': 'R_HSA_159231',
#   'Transport of Mature mRNA derived from an Intron_Containing Transcript': 'R_HSA_159236',
#   'Transport of Mature mRNAs Derived from Intronless Transcripts': 'R_HSA_159234',
#   'Transport of Ribonucleoproteins into the Host Nucleus': 'R_HSA_168271',
#   'Transport of inorganic cationsslashanions and amino acidsslasholigopeptides': 'R_HSA_425393',
#   'Transport of the SLBP Dependant Mature mRNA': 'R_HSA_159230',
#   'Transport of the SLBP independent Mature mRNA': 'R_HSA_159227',
#   'Transport of vitamins nucleosides and related molecules': 'R_HSA_425397',
#   'Triglyceride Biosynthesis': 'R_HSA_75109',
#   'Tristetraprolin TTP ZFP36 binds and destabilizes mRNA': 'R_HSA_450513',
#   'Ubiquitin Mediated Degradation of Phosphorylated Cdc25A': 'R_HSA_69601',
#   'Ubiquitin_dependent degradation of Cyclin D': 'R_HSA_75815',
#   'Ubiquitin_dependent degradation of Cyclin D1': 'R_HSA_69229',
#   'Unblocking of NMDA receptor glutamate binding and activation': 'R_HSA_438066',
#   'Unfolded Protein Response UPR': 'R_HSA_381119',
#   'Uptake and actions of bacterial toxins': 'R_HSA_5339562',
#   'VEGFR2 mediated vascular permeability': 'R_HSA_5218920',
#   'Vasopressin regulates renal water homeostasis via Aquaporins': 'R_HSA_432040',
#   'Vif_mediated degradation of APOBEC3G': 'R_HSA_180585',
#   'Viral Messenger RNA Synthesis': 'R_HSA_168325',
#   'Viral mRNA Translation': 'R_HSA_192823',
#   'Visual phototransduction': 'R_HSA_2187338',
#   'Voltage gated Potassium channels': 'R_HSA_1296072',
#   'Vpr_mediated nuclear import of PICs': 'R_HSA_180910',
#   'Vpu mediated degradation of CD4': 'R_HSA_180534',
#   'VxPx cargo_targeting to cilium': 'R_HSA_5620916',
#   'WNT ligand biogenesis and trafficking': 'R_HSA_3238698',
#   'WNT5A_dependent internalization of FZD4': 'R_HSA_5099900',
#   'XBP1S activates chaperone genes': 'R_HSA_381038',
#   'Xenobiotics': 'R_HSA_211981',
#   'YAP1_ and WWTR1 TAZ_stimulated gene expression': 'R_HSA_2032785',
#   'ZBP1DAI mediated induction of type I IFNs': 'R_HSA_1606322',
#   'Zinc transporters': 'R_HSA_435354',
#   'activated TAK1 mediates p38 MAPK activation': 'R_HSA_450302',
#   'cGMP effects': 'R_HSA_418457',
#   'eNOS activation and regulation': 'R_HSA_203765',
#   'mRNA 3 _end processing': 'R_HSA_72187',
#   'mRNA Capping': 'R_HSA_72086',
#   'mRNA Splicing _ Minor Pathway': 'R_HSA_72165',
#   'mRNA decay by 5  to 3  exoribonuclease': 'R_HSA_430039',
#   'mTOR signalling': 'R_HSA_165159',
#   'mTORC1_mediated signalling': 'R_HSA_166208',
#   'p130Cas linkage to MAPK signaling for integrins': 'R_HSA_372708',
#   'p53_Dependent G1 DNA Damage Response': 'R_HSA_69563',
#   'p53_Dependent G1slashS DNA damage checkpoint': 'R_HSA_69580',
#   'p53_Independent DNA Damage Response': 'R_HSA_69610',
#   'p53_Independent G1slashS DNA damage checkpoint': 'R_HSA_69613',
#   'p75 NTR receptor_mediated signalling': 'R_HSA_193704',
#   'p75NTR signals via NF_kB': 'R_HSA_193639',
#   'phosphorylation site mutants of CTNNB1 are not targeted to the proteasome by the destruction complex': 'R_HSA_4839743',
#   'rRNA modification in the nucleus': 'R_HSA_6790901',
#   'snRNP Assembly': 'R_HSA_191859',
#   'tRNA Aminoacylation': 'R_HSA_379724',
#   'tRNA modification in the nucleus and cytosol': 'R_HSA_6782315',
#   'tRNA processing in the nucleus': 'R_HSA_6784531',
#   'trans_Golgi Network Vesicle Budding': 'R_HSA_199992'})
